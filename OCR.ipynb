# %% [markdown]
# ####
# !pip install pytesseract
#
# #### dwonload
# https://github.com/UB-Mannheim/tesseract/wiki

# %%
import pytesseract
from PIL import Image
import matplotlib.pyplot as plt
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
import os
# Out:
# 'C:\\Users\\Vishal\\Downloads\\yolo_ocr'

# %%
from glob import glob
glob(os.getcwd()+'\\*')
# Out:
# ['C:\\Users\\Vishal\\Downloads\\yolo_ocr\\img1.png',
#  'C:\\Users\\Vishal\\Downloads\\yolo_ocr\\img2.png',
#  'C:\\Users\\Vishal\\Downloads\\yolo_ocr\\img3.png',
#  'C:\\Users\\Vishal\\Downloads\\yolo_ocr\\img4.png',
#  'C:\\Users\\Vishal\\Downloads\\yolo_ocr\\img5.jpg',
#  'C:\\Users\\Vishal\\Downloads\\yolo_ocr\\img7.png',
#  'C:\\Users\\Vishal\\Downloads\\yolo_ocr\\Untitled.ipynb']

# %%
I=Image.open('C:\\Users\\Vishal\\Downloads\\yolo_ocr\\img1.png')
text =pytesseract.image_to_string(I,lang='eng')

# %%
I
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=726x315 at 0x23AB921F250>

# %%
text
# Out:
# 'SUM iM X vf | =SumByColor(A1:D10,A2)\n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\naA | 8 | ¢ | oJ ie F G\n1 356) 249) 497,329 Color Sum\n\n2 352| 206 427/229 Red ESumByColor(A1:010,A2)\n3 135) 294250142 Blue\n\n4 162| 285, 133,169 Black\n\n5 211 424438307\n\n6 445,347, 464124,\n\n7 374,284) 260 335\n\n8 306 187| 377,460\n\n9 337,466,491 295)\n\n10 135,264,235, ——303)\n\n \n\n \n\n \n\n \n\x0c'

# %%
import cv2
img=cv2.imread('C:\\Users\\Vishal\\Downloads\\yolo_ocr\\img8.png')
boxes=pytesseract.image_to_boxes(img)
H,W,_=img.shape
for b in boxes.splitlines():
    b=b.split(' ')
    #box.append(b)
    x,y,w,h=int(b[1]),int(b[2]),int(b[3]),int(b[4])
    cv2.rectangle(img,(x,H-y),(w,H-h),(0,255,0),1)
cv2.imshow('result',img)
cv2.waitKey(0)
